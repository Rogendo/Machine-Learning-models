# %% [markdown]
# <a href="https://colab.research.google.com/github/Rogendo/Machine-Learning-models/blob/main/jenganlp_testrun.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip uninstall torchvision

# %%
# !pip install --upgrade pip

# %%
# !pip install --no-deps -i https://test.pypi.org/simple/ jenga-nlp==2.0.0
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# Collecting jenga-nlp==2.0.0
#   Downloading https://test-files.pythonhosted.org/packages/d9/66/fda75a5494a75609d67dd9afb616d90da1e122380d77a3e0e7b6ecff1f4f/jenga_nlp-2.0.0-py3-none-any.whl.metadata (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 1.4 MB/s eta 0:00:00
# Downloading https://test-files.pythonhosted.org/packages/d9/66/fda75a5494a75609d67dd9afb616d90da1e122380d77a3e0e7b6ecff1f4f/jenga_nlp-2.0.0-py3-none-any.whl (111 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.6/111.6 kB 3.1 MB/s eta 0:00:00
# Installing collected packages: jenga-nlp
# Successfully installed jenga-nlp-2.0.0

# %%
# !pip install mlflow
# Out:
# Collecting mlflow
#   Downloading mlflow-3.14.0-py3-none-any.whl.metadata (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 3.0 MB/s eta 0:00:00
# Collecting mlflow-skinny==3.14.0 (from mlflow)
#   Downloading mlflow_skinny-3.14.0-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 3.2 MB/s eta 0:00:00
# Collecting mlflow-tracing==3.14.0 (from mlflow)
#   Downloading mlflow_tracing-3.14.0-py3-none-any.whl.metadata (19 kB)
# Collecting Flask-CORS<7 (from mlflow)
#   Downloading flask_cors-6.0.5-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: Flask<4 in /usr/local/lib/python3.12/dist-packages (from mlflow) (3.1.3)
# Requirement already satisfied: aiohttp<4,>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from mlflow) (3.14.1)
# Collecting alembic!=1.10.0,<2 (from mlflow)
#   Downloading alembic-1.18.5-py3-none-any.whl.metadata (7.2 kB)
# Collecting cryptography<49,>=43.0.0 (from mlflow)
#   Downloading cryptography-48.0.1-cp311-abi3-manylinux_2_34_x86_64.whl.metadata (4.3 kB)
# Collecting docker<8,>=4.0.0 (from mlflow)
#   Downloading docker-7.2.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow)
#   Downloading graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting gunicorn<27 (from mlflow)
#   Downloading gunicorn-26.0.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting huey<4,>=2.5.4 (from mlflow)
#   Downloading huey-3.3.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: matplotlib<4 in /usr/local/lib/python3.12/dist-packages (from mlflow) (3.10.0)
# Requirement already satisfied: numpy<3 in /usr/local/lib/python3.12/dist-packages (from mlflow) (2.0.2)
# Requirement already satisfied: pandas<3 in /usr/local/lib/python3.12/dist-packages (from mlflow) (2.2.2)
# Requirement already satisfied: pyarrow<25,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow) (18.1.0)
# Requirement already satisfied: scikit-learn<2 in /usr/local/lib/python3.12/dist-packages (from mlflow) (1.6.1)
# Requirement already satisfied: scipy<2 in /usr/local/lib/python3.12/dist-packages (from mlflow) (1.16.3)
# Collecting skops<1 (from mlflow)
#   Downloading skops-0.14.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from mlflow) (2.0.51)
# Requirement already satisfied: cachetools<8,>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.14.0->mlflow) (6.2.6)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.14.0->mlflow) (8.4.2)
# Requirement already satisfied: cloudpickle<4 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.14.0->mlflow) (3.1.2)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==3.14.0->mlflow)
#   Downloading databricks_sdk-0.122.0-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: fastapi<1 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.14.0->mlflow) (0.139.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.14.0->mlflow) (3.1.51)
# Requirement already satisfied: importlib_metadata!=4.7.0,<10,>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.14.0->mlflow) (9.0.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.14.0->mlflow) (1.42.1)
# Collecting opentelemetry-proto<3,>=1.9.0 (from mlflow-skinny==3.14.0->mlflow)
#   Downloading opentelemetry_proto-1.44.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.14.0->mlflow) (1.42.1)
# Requirement already satisfied: packaging<27 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.14.0->mlflow) (26.2)
# Requirement already satisfied: protobuf<8,>=3.12.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.14.0->mlflow) (5.29.6)
# Requirement already satisfied: pydantic<3,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.14.0->mlflow) (2.13.4)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.14.0->mlflow) (1.2.2)
# Requirement already satisfied: pyyaml<7,>=5.1 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.14.0->mlflow) (6.0.3)
# Requirement already satisfied: requests<3,>=2.17.3 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.14.0->mlflow) (2.32.4)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.14.0->mlflow) (0.5.5)
# Requirement already satisfied: starlette<2 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.14.0->mlflow) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.14.0->mlflow) (4.16.0)
# Requirement already satisfied: uvicorn<1 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.14.0->mlflow) (0.51.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.7.0->mlflow) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.7.0->mlflow) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.7.0->mlflow) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.7.0->mlflow) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.7.0->mlflow) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.7.0->mlflow) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.7.0->mlflow) (1.24.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic!=1.10.0,<2->mlflow) (1.1.3)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cryptography<49,>=43.0.0->mlflow) (2.1.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from docker<8,>=4.0.0->mlflow) (2.5.0)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from Flask<4->mlflow) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from Flask<4->mlflow) (3.1.8)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_core-3.2.11-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /usr/local/lib/python3.12/dist-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->mlflow) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->mlflow) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->mlflow) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->mlflow) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->mlflow) (3.3.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3->mlflow) (2026.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<2->mlflow) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: prettytable>=3.9 in /usr/local/lib/python3.12/dist-packages (from skops<1->mlflow) (3.18.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.5.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->cryptography<49,>=43.0.0->mlflow) (3.0)
# Requirement already satisfied: google-auth~=2.0 in /usr/local/lib/python3.12/dist-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.14.0->mlflow) (2.49.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1->mlflow-skinny==3.14.0->mlflow) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1->mlflow-skinny==3.14.0->mlflow) (0.0.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.14.0->mlflow) (4.0.12)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib_metadata!=4.7.0,<10,>=3.7.0->mlflow-skinny==3.14.0->mlflow) (4.1.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.63b1 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.14.0->mlflow) (0.63b1)
# Requirement already satisfied: wcwidth>=0.3.5 in /usr/local/lib/python3.12/dist-packages (from prettytable>=3.9->skops<1->mlflow) (0.8.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.14.0->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.14.0->mlflow) (2.46.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.17.3->mlflow-skinny==3.14.0->mlflow) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.17.3->mlflow-skinny==3.14.0->mlflow) (3.18)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.17.3->mlflow-skinny==3.14.0->mlflow) (2026.6.17)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.12/dist-packages (from starlette<2->mlflow-skinny==3.14.0->mlflow) (4.14.2)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn<1->mlflow-skinny==3.14.0->mlflow) (0.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.14.0->mlflow) (5.0.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.14.0->mlflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.14.0->mlflow) (4.9.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.14.0->mlflow) (0.6.4)
# Downloading mlflow-3.14.0-py3-none-any.whl (12.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 44.3 MB/s eta 0:00:00
# Downloading mlflow_skinny-3.14.0-py3-none-any.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 74.2 MB/s eta 0:00:00
# Downloading mlflow_tracing-3.14.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 43.6 MB/s eta 0:00:00
# Downloading alembic-1.18.5-py3-none-any.whl (264 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.7/264.7 kB 17.3 MB/s eta 0:00:00
# Downloading cryptography-48.0.1-cp311-abi3-manylinux_2_34_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 49.6 MB/s eta 0:00:00
# Downloading docker-7.2.0-py3-none-any.whl (148 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.8/148.8 kB 9.7 MB/s eta 0:00:00
# Downloading flask_cors-6.0.5-py3-none-any.whl (16 kB)
# Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 6.7 MB/s eta 0:00:00
# Downloading gunicorn-26.0.0-py3-none-any.whl (212 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.0/212.0 kB 14.0 MB/s eta 0:00:00
# Downloading huey-3.3.0-py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.3/121.3 kB 8.5 MB/s eta 0:00:00
# Downloading skops-0.14.0-py3-none-any.whl (132 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.2/132.2 kB 8.7 MB/s eta 0:00:00
# Downloading databricks_sdk-0.122.0-py3-none-any.whl (969 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 969.1/969.1 kB 40.4 MB/s eta 0:00:00
# Downloading graphql_core-3.2.11-py3-none-any.whl (214 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.9/214.9 kB 13.2 MB/s eta 0:00:00
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading opentelemetry_proto-1.44.0-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 4.4 MB/s eta 0:00:00
# Installing collected packages: huey, opentelemetry-proto, gunicorn, graphql-core, graphql-relay, docker, cryptography, alembic, skops, graphene, Flask-CORS, databricks-sdk, mlflow-tracing, mlflow-skinny, mlflow
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 49.0.0
#     Uninstalling cryptography-49.0.0:
#       Successfully uninstalled cryptography-49.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jenga-nlp 2.0.0 requires bitsandbytes>=0.43.0, which is not installed.
# pyopenssl 26.3.0 requires cryptography<50,>=49.0.0, but you have cryptography 48.0.1 which is incompatible.
# Successfully installed Flask-CORS-6.0.5 alembic-1.18.5 cryptography-48.0.1 databricks-sdk-0.122.0 docker-7.2.0 graphene-3.4.3 graphql-core-3.2.11 graphql-relay-3.2.0 gunicorn-26.0.0 huey-3.3.0 mlflow-3.14.0 mlflow-skinny-3.14.0 mlflow-tracing-3.14.0 opentelemetry-proto-1.44.0 skops-0.14.0

# %%
# ! mlflow ui  --backend-store-uri sqlite:///mlflow.db  --default-artifact-root ./mlartifacts   --host 0.0.0.0  --port 5000

# %%
import subprocess

# Your exact command broken down into a list arguments for background execution
mlflow_cmd = [
    "mlflow", "ui",
    "--backend-store-uri", "sqlite:///mlflow.db",
    "--default-artifact-root", "./mlartifacts",
    "--host", "0.0.0.0",
    "--port", "5000" #,
    # "--allowed-hosts", "*"
]

# Run the server in the background
mlflow_process = subprocess.Popen(mlflow_cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
print("MLflow Tracking Server started successfully with SQLite!")
# Out:
# MLflow Tracking Server started successfully with SQLite!

# %%
# !pip install pyngrok -q

# %%
from google.colab import userdata
from pyngrok import ngrok

# Fetch token from Colab Secrets
ngrok_token = userdata.get('NGROK_TOKEN')
ngrok.set_auth_token(ngrok_token)

# %%
# Open a public HTTP tunnel
public_url = ngrok.connect(5000, host_header="localhost:5000")
print("MLflow UI Public URL:", public_url.public_url)
# Out:
# MLflow UI Public URL: https://d8e8-34-178-80-22.ngrok-free.app

# %% [markdown]
#  ## **Log a Test Run (Optional)**
#  To verify everything works, initialize an MLflow experiment and log some mock metrics

# %%
import mlflow

# Point MLflow to the local server
mlflow.set_tracking_uri("http://127.0.0.1:5000")
mlflow.set_experiment("Colab_Demo")

with mlflow.start_run():
    mlflow.log_param("optimizer", "Adam")
    mlflow.log_metric("accuracy", 0.95)
    print("Logged metrics successfully! Refresh your ngrok URL to view them.")
# Out:
# 2026/07/24 22:04:05 INFO mlflow.tracking.fluent: Experiment with name 'Colab_Demo' does not exist. Creating a new experiment.
# Logged metrics successfully! Refresh your ngrok URL to view them.
# 🏃 View run unique-shoat-938 at: http://127.0.0.1:5000/#/experiments/3/runs/cc7ef64541f442c5b8eb286854dba767
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3

# %%
import mlflow

# Set the tracking URI to your local SQLite database file
mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("My_SQLite_Experiment")
# Out:
# 2026/07/24 22:10:11 INFO mlflow.tracking.fluent: Experiment with name 'My_SQLite_Experiment' does not exist. Creating a new experiment.
# <Experiment: artifact_location='/content/mlruns/4', creation_time=1784931011063, effective_trace_archival_retention=None, experiment_id='4', last_update_time=1784931011063, lifecycle_stage='active', name='My_SQLite_Experiment', tags={}, trace_location=None, workspace='default'>

# %%
# !python -m jenga_nlp
# Out:
# JengaNLP command line
#
# Usage:
#   python -m jenga_nlp <command> [options]
#
# Common commands:
#   python -m jenga_nlp train --config configs/fixture_mpesa_fraud_cpu.yaml --device cpu
#   python -m jenga_nlp evaluate --config configs/fixture_mpesa_fraud_cpu.yaml --model-dir /tmp/jenganlp_fixture_mpesa_fraud_cpu --device cpu
#   python -m jenga_nlp predict --config configs/fixture_mpesa_fraud_cpu.yaml --model-dir /tmp/jenganlp_fixture_mpesa_fraud_cpu --text "Your text here"
#   python -m jenga_nlp resume --config configs/fixture_mpesa_fraud_cpu.yaml --run-dir /tmp/jenganlp_fixture_mpesa_fraud_cpu
#   python -m jenga_nlp backends status --config configs/fixture_mpesa_fraud_cpu.yaml
#   python -m jenga_nlp asr serve --model-name openai/whisper-small --audio sample.wav
#
# Commands:
#   train       Train a text model from a YAML config.
#   evaluate    Evaluate a saved model directory.
#   predict     Run inference with a saved model directory.
#   resume      Resume training from a saved run directory.
#   backends    Check or initialize configured integrations.
#   asr         Whisper speech-to-text serving and fine-tuning commands.
#
# For command-specific help:
#   python -m jenga_nlp train -h
#   python -m jenga_nlp predict -h
#   python -m jenga_nlp asr train -h

# %%
# !cat /content/fixture_multitask_cpu.yaml
# Out:
# project_name: fixture_multitask_cpu
#
# model:
#   base_model: distilbert-base-uncased
#   dropout: 0.1
#
# tokenizer:
#   max_length: 256
#   padding: max_length
#   truncation: true
#
# tasks:
#   - name: mpesa_fraud_detection
#     type: single_label_classification
#     data_path: /content/sample_classification.jsonl
#     text_column: text
#     label_column: label
#     heads:
#       - name: fraud_head
#         num_labels: 2
#
#   - name: mpesa_sentiment
#     type: sentiment
#     data_path: /content/sample_sentiment.jsonl
#     text_column: text
#     label_column: label
#     heads:
#       - name: sentiment_head
#         num_labels: 3
#
#   - name: call_qa_scoring
#     type: qa_scoring
#     data_path: /content/sample_qa_transcripts.jsonl
#     text_column: transcript
#     label_column: labels
#     heads:
#       - name: opening
#         num_labels: 1
#         weight: 1.0
#       - name: listening
#         num_labels: 5
#         weight: 1.5
#       - name: proactiveness
#         num_labels: 3
#         weight: 1.0
#       - name: resolution
#         num_labels: 5
#         weight: 2.0
#       - name: hold
#         num_labels: 2
#         weight: 0.5
#       - name: closing
#         num_labels: 1
#         weight: 1.0
#
# training:
#   output_dir: /content/jenganlp_fixture_multitask_cpu
#   learning_rate: 0.00005
#   batch_size: 4
#   eval_batch_size: 4
#   num_epochs: 4
#   weight_decay: 0.0
#   warmup_steps: 0
#   max_grad_norm: 1.0
#   gradient_accumulation_steps: 1
#   use_amp: false
#   device: cpu
#   task_sampling: round_robin
#   metric_for_best_model: eval_loss
#   greater_is_better: false
#   logging:
#     service: mlflow
#     experiment_name: fixture_multitask_cpu
#     tracking_uri: https://d8e8-34-178-80-22.ngrok-free.app
#     log_every_n_steps: 1
#   checkpoint:
#     save_every_n_epochs: 1
#     save_best: true
#     max_checkpoints: 1
#   data:
#     test_size: 0.2
#     seed: 42
#     num_workers: 0
#     pin_memory: false

# %%
# !python -m jenga_nlp train  --config /content/fixture_multitask_cpu.yaml --device cpu
# Out:
# 2026-07-24 22:28:41,267 | INFO | jenga_nlp.activity | [system] info run started: fixture_multitask_cpu
# 2026-07-24 22:28:41,268 | INFO | jenga_nlp.activity | [system] info loading tokenizer
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-07-24 22:28:42,287 | INFO | jenga_nlp.data.processor | Processing data for task: mpesa_fraud_detection (type: TaskType.SINGLE_LABEL_CLASSIFICATION)
# 2026-07-24 22:28:42,293 | INFO | jenga_nlp.data.processor |   Loaded 20 rows from sample_classification.jsonl
# Map: 100% 20/20 [00:00<00:00, 1661.57 examples/s]
# 2026-07-24 22:28:42,469 | INFO | jenga_nlp.data.processor |   Task 'mpesa_fraud_detection': 16 train, 4 eval samples
# 2026-07-24 22:28:42,470 | INFO | jenga_nlp.data.processor | Processing data for task: mpesa_sentiment (type: TaskType.SENTIMENT)
# 2026-07-24 22:28:42,473 | INFO | jenga_nlp.data.processor |   Loaded 15 rows from sample_sentiment.jsonl
# Map: 100% 15/15 [00:00<00:00, 1506.36 examples/s]
# 2026-07-24 22:28:42,649 | INFO | jenga_nlp.data.processor |   Task 'mpesa_sentiment': 12 train, 3 eval samples
# 2026-07-24 22:28:42,649 | INFO | jenga_nlp.data.processor | Processing data for task: call_qa_scoring (type: TaskType.QA_SCORING)
# 2026-07-24 22:28:42,652 | INFO | jenga_nlp.data.processor |   Loaded 10 rows from sample_qa_transcripts.jsonl
# Map: 100% 10/10 [00:00<00:00, 599.93 examples/s]
# 2026-07-24 22:28:42,872 | INFO | jenga_nlp.data.processor |   Task 'call_qa_scoring': 8 train, 2 eval samples
# 2026-07-24 22:28:42,873 | INFO | jenga_nlp.activity | [system] info datasets processed
# 2026-07-24 22:28:42,994 | INFO | jenga_nlp.tasks.registry | Creating task 'mpesa_fraud_detection' of type 'single_label_classification' with hidden_size=768
# 2026-07-24 22:28:42,995 | INFO | jenga_nlp.tasks.registry | Creating task 'mpesa_sentiment' of type 'sentiment' with hidden_size=768
# 2026-07-24 22:28:42,995 | INFO | jenga_nlp.tasks.registry | Creating task 'call_qa_scoring' of type 'qa_scoring' with hidden_size=768
# Loading weights: 100% 100/100 [00:00<00:00, 5074.16it/s]
# [transformers] DistilBertModel LOAD REPORT from: distilbert-base-uncased
# Key                     | Status     |  |
# ------------------------+------------+--+-
# vocab_layer_norm.bias   | UNEXPECTED |  |
# vocab_layer_norm.weight | UNEXPECTED |  |
# vocab_projector.bias    | UNEXPECTED |  |
# vocab_transform.bias    | UNEXPECTED |  |
# vocab_transform.weight  | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 2026-07-24 22:28:46,044 | INFO | jenga_nlp.training.callbacks | MLflow UI: https://d8e8-34-178-80-22.ngrok-free.app/#/experiments/5/runs/6946dfb034b741259825c665d8cf1e5b
# 2026-07-24 22:28:46,294 | INFO | jenga_nlp.training.callbacks | MLflow experiment: fixture_multitask_cpu
# 2026-07-24 22:28:46,296 | INFO | jenga_nlp.training.trainer | Starting training: 4 epochs, 36 total steps, device=cpu
# 2026-07-24 22:28:46,296 | INFO | jenga_nlp.activity | [train] train_started training started
# Training:   0% 0/36 [00:00<?, ?it/s]2026-07-24 22:28:46,300 | INFO | jenga_nlp.activity | [train] epoch_started epoch 1 started epoch=0
# 2026-07-24 22:28:55,705 | INFO | jenga_nlp.activity | [train] step_logged step 1 loss 0.7581 step=1
# Training:   3% 1/36 [00:09<05:41,  9.75s/it, epoch=1, loss=0.7581]2026-07-24 22:29:04,044 | INFO | jenga_nlp.activity | [train] step_logged step 2 loss 1.4140 step=2
# Training:   6% 2/36 [00:18<05:03,  8.93s/it, epoch=1, loss=1.4140]2026-07-24 22:29:10,833 | INFO | jenga_nlp.activity | [train] step_logged step 3 loss 4.8565 step=3
# Training:   8% 3/36 [00:24<04:22,  7.94s/it, epoch=1, loss=4.8565]2026-07-24 22:29:18,970 | INFO | jenga_nlp.activity | [train] step_logged step 4 loss 0.6806 step=4
# Training:  11% 4/36 [00:33<04:16,  8.02s/it, epoch=1, loss=0.6806]2026-07-24 22:29:25,339 | INFO | jenga_nlp.activity | [train] step_logged step 5 loss 1.0059 step=5
# Training:  14% 5/36 [00:39<03:50,  7.42s/it, epoch=1, loss=1.0059]2026-07-24 22:29:33,522 | INFO | jenga_nlp.activity | [train] step_logged step 6 loss 4.9082 step=6
# Training:  17% 6/36 [00:47<03:50,  7.70s/it, epoch=1, loss=4.9082]2026-07-24 22:29:40,008 | INFO | jenga_nlp.activity | [train] step_logged step 7 loss 0.6887 step=7
# Training:  19% 7/36 [00:54<03:31,  7.29s/it, epoch=1, loss=0.6887]2026-07-24 22:29:47,928 | INFO | jenga_nlp.activity | [train] step_logged step 8 loss 1.0215 step=8
# Training:  22% 8/36 [01:01<03:29,  7.49s/it, epoch=1, loss=1.0215]2026-07-24 22:29:54,238 | INFO | jenga_nlp.activity | [train] step_logged step 9 loss 0.5560 step=9
# Training:  25% 9/36 [01:08<03:12,  7.12s/it, epoch=1, loss=0.5560]2026-07-24 22:29:58,464 | INFO | jenga_nlp.training.trainer | Epoch 1/4 - Metrics: {'mpesa_fraud_detection_fraud_head_accuracy': 1.0, 'mpesa_fraud_detection_fraud_head_precision': 1.0, 'mpesa_fraud_detection_fraud_head_recall': 1.0, 'mpesa_fraud_detection_fraud_head_f1': 1.0, 'mpesa_sentiment_sentiment_head_accuracy': 0.3333333333333333, 'mpesa_sentiment_sentiment_head_precision': 0.1111111111111111, 'mpesa_sentiment_sentiment_head_recall': 0.3333333333333333, 'mpesa_sentiment_sentiment_head_f1': 0.16666666666666666, 'call_qa_scoring_opening_precision': 0.5, 'call_qa_scoring_opening_recall': 0.5, 'call_qa_scoring_opening_f1': 0.5, 'call_qa_scoring_listening_precision': 0.6666666666666666, 'call_qa_scoring_listening_recall': 0.2857142857142857, 'call_qa_scoring_listening_f1': 0.4, 'call_qa_scoring_proactiveness_precision': 0.6, 'call_qa_scoring_proactiveness_recall': 1.0, 'call_qa_scoring_proactiveness_f1': 0.75, 'call_qa_scoring_resolution_precision': 1.0, 'call_qa_scoring_resolution_recall': 0.3333333333333333, 'call_qa_scoring_resolution_f1': 0.5, 'call_qa_scoring_hold_precision': 0.5, 'call_qa_scoring_hold_recall': 0.3333333333333333, 'call_qa_scoring_hold_f1': 0.4, 'call_qa_scoring_closing_precision': 0.5, 'call_qa_scoring_closing_recall': 0.5, 'call_qa_scoring_closing_f1': 0.5, 'eval_loss': 2.1650049090385437, 'train_loss_avg': 1.7655003203286066}
# 2026-07-24 22:29:58,464 | INFO | jenga_nlp.activity | [eval] metrics_logged epoch 1 metrics logged epoch=0
# 2026-07-24 22:30:14,617 | INFO | jenga_nlp.training.callbacks | Checkpoint saved (epoch 0): /content/jenganlp_fixture_multitask_cpu/checkpoints/epoch_0
# 2026-07-24 22:30:14,618 | INFO | jenga_nlp.activity | [checkpoint] checkpoint_saved checkpoint saved: /content/jenganlp_fixture_multitask_cpu/checkpoints/epoch_0 epoch=0 step=9
# 2026-07-24 22:30:30,129 | INFO | jenga_nlp.training.callbacks | Checkpoint saved (best): /content/jenganlp_fixture_multitask_cpu/checkpoints/best
# 2026-07-24 22:30:30,132 | INFO | jenga_nlp.activity | [checkpoint] checkpoint_saved checkpoint saved: /content/jenganlp_fixture_multitask_cpu/checkpoints/best epoch=0 step=9
# 2026-07-24 22:30:30,136 | INFO | jenga_nlp.activity | [train] epoch_started epoch 2 started epoch=1
# 2026-07-24 22:30:36,431 | INFO | jenga_nlp.activity | [train] step_logged step 10 loss 0.4475 step=10
# Training:  28% 10/36 [01:50<07:47, 17.96s/it, epoch=2, loss=0.4475]2026-07-24 22:30:44,588 | INFO | jenga_nlp.activity | [train] step_logged step 11 loss 0.9857 step=11
# Training:  31% 11/36 [01:58<06:13, 14.96s/it, epoch=2, loss=0.9857]2026-07-24 22:30:51,069 | INFO | jenga_nlp.activity | [train] step_logged step 12 loss 4.4830 step=12
# Training:  33% 12/36 [02:05<04:57, 12.38s/it, epoch=2, loss=4.4830]2026-07-24 22:30:59,482 | INFO | jenga_nlp.activity | [train] step_logged step 13 loss 0.3133 step=13
# Training:  36% 13/36 [02:13<04:16, 11.17s/it, epoch=2, loss=0.3133]2026-07-24 22:31:06,006 | INFO | jenga_nlp.activity | [train] step_logged step 14 loss 0.9108 step=14
# Training:  39% 14/36 [02:20<03:34,  9.77s/it, epoch=2, loss=0.9108]2026-07-24 22:31:14,802 | INFO | jenga_nlp.activity | [train] step_logged step 15 loss 4.7271 step=15
# Training:  42% 15/36 [02:28<03:18,  9.47s/it, epoch=2, loss=4.7271]2026-07-24 22:31:21,357 | INFO | jenga_nlp.activity | [train] step_logged step 16 loss 0.2217 step=16
# Training:  44% 16/36 [02:35<02:51,  8.59s/it, epoch=2, loss=0.2217]2026-07-24 22:31:29,474 | INFO | jenga_nlp.activity | [train] step_logged step 17 loss 1.0808 step=17
# Training:  47% 17/36 [02:43<02:40,  8.45s/it, epoch=2, loss=1.0808]2026-07-24 22:31:35,948 | INFO | jenga_nlp.activity | [train] step_logged step 18 loss 0.1767 step=18
# Training:  50% 18/36 [02:49<02:21,  7.86s/it, epoch=2, loss=0.1767]2026-07-24 22:31:41,738 | INFO | jenga_nlp.training.trainer | Epoch 2/4 - Metrics: {'mpesa_fraud_detection_fraud_head_accuracy': 1.0, 'mpesa_fraud_detection_fraud_head_precision': 1.0, 'mpesa_fraud_detection_fraud_head_recall': 1.0, 'mpesa_fraud_detection_fraud_head_f1': 1.0, 'mpesa_sentiment_sentiment_head_accuracy': 0.3333333333333333, 'mpesa_sentiment_sentiment_head_precision': 0.1111111111111111, 'mpesa_sentiment_sentiment_head_recall': 0.3333333333333333, 'mpesa_sentiment_sentiment_head_f1': 0.16666666666666666, 'call_qa_scoring_opening_precision': 1.0, 'call_qa_scoring_opening_recall': 1.0, 'call_qa_scoring_opening_f1': 1.0, 'call_qa_scoring_listening_precision': 0.6666666666666666, 'call_qa_scoring_listening_recall': 0.8571428571428571, 'call_qa_scoring_listening_f1': 0.75, 'call_qa_scoring_proactiveness_precision': 0.6666666666666666, 'call_qa_scoring_proactiveness_recall': 0.6666666666666666, 'call_qa_scoring_proactiveness_f1': 0.6666666666666666, 'call_qa_scoring_resolution_precision': 0.7142857142857143, 'call_qa_scoring_resolution_recall': 0.8333333333333334, 'call_qa_scoring_resolution_f1': 0.7692307692307693, 'call_qa_scoring_hold_precision': 0.75, 'call_qa_scoring_hold_recall': 1.0, 'call_qa_scoring_hold_f1': 0.8571428571428571, 'call_qa_scoring_closing_precision': 0.5, 'call_qa_scoring_closing_recall': 0.5, 'call_qa_scoring_closing_f1': 0.5, 'eval_loss': 1.9118708123763402, 'train_loss_avg': 1.482964015669293}
# 2026-07-24 22:31:41,739 | INFO | jenga_nlp.activity | [eval] metrics_logged epoch 2 metrics logged epoch=1
# 2026-07-24 22:31:54,407 | INFO | jenga_nlp.training.callbacks | Checkpoint saved (epoch 1): /content/jenganlp_fixture_multitask_cpu/checkpoints/epoch_1
# 2026-07-24 22:31:54,408 | INFO | jenga_nlp.activity | [checkpoint] checkpoint_saved checkpoint saved: /content/jenganlp_fixture_multitask_cpu/checkpoints/epoch_1 epoch=1 step=18
# 2026-07-24 22:32:08,571 | INFO | jenga_nlp.training.callbacks | Checkpoint saved (best): /content/jenganlp_fixture_multitask_cpu/checkpoints/best
# 2026-07-24 22:32:08,571 | INFO | jenga_nlp.activity | [checkpoint] checkpoint_saved checkpoint saved: /content/jenganlp_fixture_multitask_cpu/checkpoints/best epoch=1 step=18
# 2026-07-24 22:32:08,572 | INFO | jenga_nlp.activity | [train] epoch_started epoch 3 started epoch=2
# 2026-07-24 22:32:15,280 | INFO | jenga_nlp.activity | [train] step_logged step 19 loss 0.1014 step=19
# Training:  53% 19/36 [03:29<04:54, 17.31s/it, epoch=3, loss=0.1014]2026-07-24 22:32:24,218 | INFO | jenga_nlp.activity | [train] step_logged step 20 loss 0.7340 step=20
# Training:  56% 20/36 [03:38<03:56, 14.80s/it, epoch=3, loss=0.7340]2026-07-24 22:32:31,263 | INFO | jenga_nlp.activity | [train] step_logged step 21 loss 4.2423 step=21
# Training:  58% 21/36 [03:45<03:06, 12.47s/it, epoch=3, loss=4.2423]2026-07-24 22:32:40,020 | INFO | jenga_nlp.activity | [train] step_logged step 22 loss 0.1005 step=22
# Training:  61% 22/36 [03:54<02:38, 11.35s/it, epoch=3, loss=0.1005]2026-07-24 22:32:49,138 | INFO | jenga_nlp.activity | [train] step_logged step 23 loss 0.6483 step=23
# Training:  64% 23/36 [04:03<02:18, 10.68s/it, epoch=3, loss=0.6483]2026-07-24 22:32:56,356 | INFO | jenga_nlp.activity | [train] step_logged step 24 loss 3.9930 step=24
# Training:  67% 24/36 [04:10<01:55,  9.65s/it, epoch=3, loss=3.9930]2026-07-24 22:33:04,496 | INFO | jenga_nlp.activity | [train] step_logged step 25 loss 0.0562 step=25
# Training:  69% 25/36 [04:18<01:41,  9.21s/it, epoch=3, loss=0.0562]2026-07-24 22:33:11,876 | INFO | jenga_nlp.activity | [train] step_logged step 26 loss 0.6843 step=26
# Training:  72% 26/36 [04:25<01:26,  8.65s/it, epoch=3, loss=0.6843]2026-07-24 22:33:21,681 | INFO | jenga_nlp.activity | [train] step_logged step 27 loss 0.0414 step=27
# Training:  75% 27/36 [04:35<01:20,  8.99s/it, epoch=3, loss=0.0414]2026-07-24 22:33:26,124 | INFO | jenga_nlp.training.trainer | Epoch 3/4 - Metrics: {'mpesa_fraud_detection_fraud_head_accuracy': 1.0, 'mpesa_fraud_detection_fraud_head_precision': 1.0, 'mpesa_fraud_detection_fraud_head_recall': 1.0, 'mpesa_fraud_detection_fraud_head_f1': 1.0, 'mpesa_sentiment_sentiment_head_accuracy': 0.3333333333333333, 'mpesa_sentiment_sentiment_head_precision': 0.16666666666666666, 'mpesa_sentiment_sentiment_head_recall': 0.3333333333333333, 'mpesa_sentiment_sentiment_head_f1': 0.2222222222222222, 'call_qa_scoring_opening_precision': 1.0, 'call_qa_scoring_opening_recall': 1.0, 'call_qa_scoring_opening_f1': 1.0, 'call_qa_scoring_listening_precision': 0.7, 'call_qa_scoring_listening_recall': 1.0, 'call_qa_scoring_listening_f1': 0.8235294117647058, 'call_qa_scoring_proactiveness_precision': 0.6666666666666666, 'call_qa_scoring_proactiveness_recall': 0.6666666666666666, 'call_qa_scoring_proactiveness_f1': 0.6666666666666666, 'call_qa_scoring_resolution_precision': 0.7142857142857143, 'call_qa_scoring_resolution_recall': 0.8333333333333334, 'call_qa_scoring_resolution_f1': 0.7692307692307693, 'call_qa_scoring_hold_precision': 0.75, 'call_qa_scoring_hold_recall': 1.0, 'call_qa_scoring_hold_f1': 0.8571428571428571, 'call_qa_scoring_closing_precision': 1.0, 'call_qa_scoring_closing_recall': 1.0, 'call_qa_scoring_closing_f1': 1.0, 'eval_loss': 1.7744470834732056, 'train_loss_avg': 1.1779273396564856}
# 2026-07-24 22:33:26,124 | INFO | jenga_nlp.activity | [eval] metrics_logged epoch 3 metrics logged epoch=2
# 2026-07-24 22:33:43,228 | INFO | jenga_nlp.training.callbacks | Checkpoint saved (epoch 2): /content/jenganlp_fixture_multitask_cpu/checkpoints/epoch_2
# 2026-07-24 22:33:43,228 | INFO | jenga_nlp.activity | [checkpoint] checkpoint_saved checkpoint saved: /content/jenganlp_fixture_multitask_cpu/checkpoints/epoch_2 epoch=2 step=27
# 2026-07-24 22:33:57,474 | INFO | jenga_nlp.training.callbacks | Checkpoint saved (best): /content/jenganlp_fixture_multitask_cpu/checkpoints/best
# 2026-07-24 22:33:57,474 | INFO | jenga_nlp.activity | [checkpoint] checkpoint_saved checkpoint saved: /content/jenganlp_fixture_multitask_cpu/checkpoints/best epoch=2 step=27
# 2026-07-24 22:33:57,475 | INFO | jenga_nlp.activity | [train] epoch_started epoch 4 started epoch=3
# 2026-07-24 22:34:05,898 | INFO | jenga_nlp.activity | [train] step_logged step 28 loss 0.0354 step=28
# Training:  78% 28/36 [05:19<02:36, 19.56s/it, epoch=4, loss=0.0354]2026-07-24 22:34:12,485 | INFO | jenga_nlp.activity | [train] step_logged step 29 loss 0.6690 step=29
# Training:  81% 29/36 [05:26<01:49, 15.67s/it, epoch=4, loss=0.6690]2026-07-24 22:34:20,891 | INFO | jenga_nlp.activity | [train] step_logged step 30 loss 3.9789 step=30
# Training:  83% 30/36 [05:34<01:20, 13.49s/it, epoch=4, loss=3.9789]2026-07-24 22:34:27,358 | INFO | jenga_nlp.activity | [train] step_logged step 31 loss 0.0202 step=31
# Training:  86% 31/36 [05:41<00:56, 11.38s/it, epoch=4, loss=0.0202]2026-07-24 22:34:35,476 | INFO | jenga_nlp.activity | [train] step_logged step 32 loss 0.7133 step=32
# Training:  89% 32/36 [05:49<00:41, 10.40s/it, epoch=4, loss=0.7133]2026-07-24 22:34:41,879 | INFO | jenga_nlp.activity | [train] step_logged step 33 loss 3.6089 step=33
# Training:  92% 33/36 [05:55<00:27,  9.20s/it, epoch=4, loss=3.6089]2026-07-24 22:34:49,985 | INFO | jenga_nlp.activity | [train] step_logged step 34 loss 0.0253 step=34
# Training:  94% 34/36 [06:04<00:17,  8.87s/it, epoch=4, loss=0.0253]2026-07-24 22:34:56,350 | INFO | jenga_nlp.activity | [train] step_logged step 35 loss 0.4567 step=35
# Training:  97% 35/36 [06:10<00:08,  8.12s/it, epoch=4, loss=0.4567]2026-07-24 22:35:04,509 | INFO | jenga_nlp.activity | [train] step_logged step 36 loss 0.0199 step=36
# Training: 100% 36/36 [06:18<00:00,  8.14s/it, epoch=4, loss=0.0199]2026-07-24 22:35:08,640 | INFO | jenga_nlp.training.trainer | Epoch 4/4 - Metrics: {'mpesa_fraud_detection_fraud_head_accuracy': 1.0, 'mpesa_fraud_detection_fraud_head_precision': 1.0, 'mpesa_fraud_detection_fraud_head_recall': 1.0, 'mpesa_fraud_detection_fraud_head_f1': 1.0, 'mpesa_sentiment_sentiment_head_accuracy': 0.3333333333333333, 'mpesa_sentiment_sentiment_head_precision': 0.16666666666666666, 'mpesa_sentiment_sentiment_head_recall': 0.3333333333333333, 'mpesa_sentiment_sentiment_head_f1': 0.2222222222222222, 'call_qa_scoring_opening_precision': 1.0, 'call_qa_scoring_opening_recall': 1.0, 'call_qa_scoring_opening_f1': 1.0, 'call_qa_scoring_listening_precision': 0.7, 'call_qa_scoring_listening_recall': 1.0, 'call_qa_scoring_listening_f1': 0.8235294117647058, 'call_qa_scoring_proactiveness_precision': 0.6666666666666666, 'call_qa_scoring_proactiveness_recall': 0.6666666666666666, 'call_qa_scoring_proactiveness_f1': 0.6666666666666666, 'call_qa_scoring_resolution_precision': 0.75, 'call_qa_scoring_resolution_recall': 1.0, 'call_qa_scoring_resolution_f1': 0.8571428571428571, 'call_qa_scoring_hold_precision': 0.75, 'call_qa_scoring_hold_recall': 1.0, 'call_qa_scoring_hold_f1': 0.8571428571428571, 'call_qa_scoring_closing_precision': 1.0, 'call_qa_scoring_closing_recall': 1.0, 'call_qa_scoring_closing_f1': 1.0, 'eval_loss': 1.6803163612882297, 'train_loss_avg': 1.058642091229558}
# 2026-07-24 22:35:08,640 | INFO | jenga_nlp.activity | [eval] metrics_logged epoch 4 metrics logged epoch=3
# 2026-07-24 22:35:25,813 | INFO | jenga_nlp.training.callbacks | Checkpoint saved (epoch 3): /content/jenganlp_fixture_multitask_cpu/checkpoints/epoch_3
# 2026-07-24 22:35:25,813 | INFO | jenga_nlp.activity | [checkpoint] checkpoint_saved checkpoint saved: /content/jenganlp_fixture_multitask_cpu/checkpoints/epoch_3 epoch=3 step=36
# 2026-07-24 22:35:35,857 | INFO | jenga_nlp.training.callbacks | Checkpoint saved (best): /content/jenganlp_fixture_multitask_cpu/checkpoints/best
# 2026-07-24 22:35:35,858 | INFO | jenga_nlp.activity | [checkpoint] checkpoint_saved checkpoint saved: /content/jenganlp_fixture_multitask_cpu/checkpoints/best epoch=3 step=36
# Training: 100% 36/36 [06:49<00:00, 11.38s/it, epoch=4, loss=0.0199]
# 2026-07-24 22:35:35,858 | INFO | jenga_nlp.activity | [system] run_finished training finished
# 🏃 View run suave-sloth-349 at: https://d8e8-34-178-80-22.ngrok-free.app/#/experiments/5/runs/6946dfb034b741259825c665d8cf1e5b
# 🧪 View experiment at: https://d8e8-34-178-80-22.ngrok-free.app/#/experiments/5
# 2026-07-24 22:35:36,547 | INFO | jenga_nlp.training.callbacks | Logger closed
# 2026-07-24 22:35:42,506 | INFO | jenga_nlp.core.model | Model saved to /content/jenganlp_fixture_multitask_cpu
# 2026-07-24 22:35:42,531 | INFO | jenga_nlp.activity | [train] info training complete
# 2026-07-24 22:35:42,540 | INFO | jenga_nlp.activity | [system] info run finished: success

# %%
# !cat /content/fixture_mpesa_fraud_cpu.yaml
# Out:
# project_name: fixture_mpesa_fraud_cpu
#
# model:
#   base_model: distilbert-base-uncased
#   dropout: 0.1
#
# tokenizer:
#   max_length: 64
#   padding: max_length
#   truncation: true
#
# tasks:
#   - name: mpesa_fraud_detection
#     type: single_label_classification
#     data_path: /content/sample_classification.jsonl
#     text_column: text
#     label_column: label
#     heads:
#       - name: fraud_head
#         num_labels: 2
#
# training:
#   output_dir: /content/jenganlp_fixture_mpesa_fraud_cpu
#   learning_rate: 0.00005
#   batch_size: 2
#   eval_batch_size: 2
#   num_epochs: 3
#   weight_decay: 0.0
#   warmup_steps: 0
#   max_grad_norm: 1.0
#   gradient_accumulation_steps: 1
#   use_amp: false
#   device: cpu
#   metric_for_best_model: eval_loss
#   greater_is_better: false
#   logging:
#     service: mlflow
#     experiment_name: fixture_mpesa_fraud_cpu
#     tracking_uri: https://d8e8-34-178-80-22.ngrok-free.app
#     log_every_n_steps: 1
#   checkpoint:
#     save_every_n_epochs: 1
#     save_best: true
#     max_checkpoints: 1
#   data:
#     test_size: 0.2
#     seed: 42
#     num_workers: 0
#     pin_memory: false

# %%
# !python -m jenga_nlp train  --config /content/fixture_mpesa_fraud_cpu.yaml --device cpu
# Out:
# 2026-07-24 22:25:18,950 | INFO | jenga_nlp.activity | [system] info run started: fixture_mpesa_fraud_cpu
# 2026-07-24 22:25:18,950 | INFO | jenga_nlp.activity | [system] info loading tokenizer
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-07-24 22:25:20,055 | INFO | jenga_nlp.data.processor | Processing data for task: mpesa_fraud_detection (type: TaskType.SINGLE_LABEL_CLASSIFICATION)
# 2026-07-24 22:25:20,066 | INFO | jenga_nlp.data.processor |   Loaded 20 rows from sample_classification.jsonl
# Map: 100% 20/20 [00:00<00:00, 1071.64 examples/s]
# 2026-07-24 22:25:20,442 | INFO | jenga_nlp.data.processor |   Task 'mpesa_fraud_detection': 16 train, 4 eval samples
# 2026-07-24 22:25:20,442 | INFO | jenga_nlp.activity | [system] info datasets processed
# 2026-07-24 22:25:20,553 | INFO | jenga_nlp.tasks.registry | Creating task 'mpesa_fraud_detection' of type 'single_label_classification' with hidden_size=768
# Loading weights: 100% 100/100 [00:00<00:00, 15969.78it/s]
# [transformers] DistilBertModel LOAD REPORT from: distilbert-base-uncased
# Key                     | Status     |  |
# ------------------------+------------+--+-
# vocab_transform.weight  | UNEXPECTED |  |
# vocab_layer_norm.bias   | UNEXPECTED |  |
# vocab_transform.bias    | UNEXPECTED |  |
# vocab_layer_norm.weight | UNEXPECTED |  |
# vocab_projector.bias    | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 2026-07-24 22:25:25,027 | INFO | jenga_nlp.training.callbacks | MLflow UI: https://d8e8-34-178-80-22.ngrok-free.app/#/experiments/2/runs/78a4f288fce5477ebe577a740f64f6e1
# 2026-07-24 22:25:25,267 | INFO | jenga_nlp.training.callbacks | MLflow experiment: fixture_mpesa_fraud_cpu
# 2026-07-24 22:25:25,268 | INFO | jenga_nlp.training.trainer | Starting training: 3 epochs, 24 total steps, device=cpu
# 2026-07-24 22:25:25,268 | INFO | jenga_nlp.activity | [train] train_started training started
# Training:   0% 0/24 [00:00<?, ?it/s]2026-07-24 22:25:25,269 | INFO | jenga_nlp.activity | [train] epoch_started epoch 1 started epoch=0
# 2026-07-24 22:25:29,561 | INFO | jenga_nlp.activity | [train] step_logged step 1 loss 0.5586 step=1
# Training:   4% 1/24 [00:04<01:44,  4.54s/it, epoch=1, loss=0.5586]2026-07-24 22:25:31,736 | INFO | jenga_nlp.activity | [train] step_logged step 2 loss 1.1164 step=2
# Training:   8% 2/24 [00:06<01:09,  3.15s/it, epoch=1, loss=1.1164]2026-07-24 22:25:33,676 | INFO | jenga_nlp.activity | [train] step_logged step 3 loss 0.7482 step=3
# Training:  12% 3/24 [00:08<00:54,  2.59s/it, epoch=1, loss=0.7482]2026-07-24 22:25:36,296 | INFO | jenga_nlp.activity | [train] step_logged step 4 loss 0.3560 step=4
# Training:  17% 4/24 [00:11<00:52,  2.61s/it, epoch=1, loss=0.3560]2026-07-24 22:25:38,767 | INFO | jenga_nlp.activity | [train] step_logged step 5 loss 0.2690 step=5
# Training:  21% 5/24 [00:13<00:48,  2.56s/it, epoch=1, loss=0.2690]2026-07-24 22:25:40,548 | INFO | jenga_nlp.activity | [train] step_logged step 6 loss 1.0376 step=6
# Training:  25% 6/24 [00:15<00:41,  2.29s/it, epoch=1, loss=1.0376]2026-07-24 22:25:42,311 | INFO | jenga_nlp.activity | [train] step_logged step 7 loss 0.4476 step=7
# Training:  29% 7/24 [00:17<00:36,  2.12s/it, epoch=1, loss=0.4476]2026-07-24 22:25:44,103 | INFO | jenga_nlp.activity | [train] step_logged step 8 loss 0.5638 step=8
# Training:  33% 8/24 [00:19<00:32,  2.02s/it, epoch=1, loss=0.5638]2026-07-24 22:25:44,827 | INFO | jenga_nlp.training.trainer | Epoch 1/3 - Metrics: {'mpesa_fraud_detection_fraud_head_accuracy': 0.25, 'mpesa_fraud_detection_fraud_head_precision': 0.0625, 'mpesa_fraud_detection_fraud_head_recall': 0.25, 'mpesa_fraud_detection_fraud_head_f1': 0.1, 'eval_loss': 0.6203322410583496, 'train_loss_avg': 0.6371374800801277}
# 2026-07-24 22:25:44,828 | INFO | jenga_nlp.activity | [eval] metrics_logged epoch 1 metrics logged epoch=0
# 2026-07-24 22:25:50,492 | INFO | jenga_nlp.training.callbacks | Checkpoint saved (epoch 0): /content/jenganlp_fixture_mpesa_fraud_cpu/checkpoints/epoch_0
# 2026-07-24 22:25:50,495 | INFO | jenga_nlp.activity | [checkpoint] checkpoint_saved checkpoint saved: /content/jenganlp_fixture_mpesa_fraud_cpu/checkpoints/epoch_0 epoch=0 step=8
# 2026-07-24 22:25:59,748 | INFO | jenga_nlp.training.callbacks | Checkpoint saved (best): /content/jenganlp_fixture_mpesa_fraud_cpu/checkpoints/best
# 2026-07-24 22:25:59,749 | INFO | jenga_nlp.activity | [checkpoint] checkpoint_saved checkpoint saved: /content/jenganlp_fixture_mpesa_fraud_cpu/checkpoints/best epoch=0 step=8
# 2026-07-24 22:25:59,756 | INFO | jenga_nlp.activity | [train] epoch_started epoch 2 started epoch=1
# 2026-07-24 22:26:04,472 | INFO | jenga_nlp.activity | [train] step_logged step 9 loss 0.1801 step=9
# Training:  38% 9/24 [00:39<01:57,  7.81s/it, epoch=2, loss=0.1801]2026-07-24 22:26:08,096 | INFO | jenga_nlp.activity | [train] step_logged step 10 loss 0.7964 step=10
# Training:  42% 10/24 [00:43<01:31,  6.56s/it, epoch=2, loss=0.7964]2026-07-24 22:26:10,408 | INFO | jenga_nlp.activity | [train] step_logged step 11 loss 0.2598 step=11
# Training:  46% 11/24 [00:45<01:07,  5.16s/it, epoch=2, loss=0.2598]2026-07-24 22:26:12,268 | INFO | jenga_nlp.activity | [train] step_logged step 12 loss 0.1164 step=12
# Training:  50% 12/24 [00:47<00:49,  4.16s/it, epoch=2, loss=0.1164]2026-07-24 22:26:14,160 | INFO | jenga_nlp.activity | [train] step_logged step 13 loss 0.1787 step=13
# Training:  54% 13/24 [00:49<00:38,  3.47s/it, epoch=2, loss=0.1787]2026-07-24 22:26:15,999 | INFO | jenga_nlp.activity | [train] step_logged step 14 loss 0.1292 step=14
# Training:  58% 14/24 [00:50<00:29,  2.98s/it, epoch=2, loss=0.1292]2026-07-24 22:26:17,852 | INFO | jenga_nlp.activity | [train] step_logged step 15 loss 0.1368 step=15
# Training:  62% 15/24 [00:52<00:23,  2.64s/it, epoch=2, loss=0.1368]2026-07-24 22:26:19,763 | INFO | jenga_nlp.activity | [train] step_logged step 16 loss 0.1174 step=16
# Training:  67% 16/24 [00:54<00:19,  2.43s/it, epoch=2, loss=0.1174]2026-07-24 22:26:20,762 | INFO | jenga_nlp.training.trainer | Epoch 2/3 - Metrics: {'mpesa_fraud_detection_fraud_head_accuracy': 1.0, 'mpesa_fraud_detection_fraud_head_precision': 1.0, 'mpesa_fraud_detection_fraud_head_recall': 1.0, 'mpesa_fraud_detection_fraud_head_f1': 1.0, 'eval_loss': 0.10493611916899681, 'train_loss_avg': 0.23934725392609835}
# 2026-07-24 22:26:20,762 | INFO | jenga_nlp.activity | [eval] metrics_logged epoch 2 metrics logged epoch=1
# 2026-07-24 22:26:39,953 | INFO | jenga_nlp.training.callbacks | Checkpoint saved (epoch 1): /content/jenganlp_fixture_mpesa_fraud_cpu/checkpoints/epoch_1
# 2026-07-24 22:26:39,953 | INFO | jenga_nlp.activity | [checkpoint] checkpoint_saved checkpoint saved: /content/jenganlp_fixture_mpesa_fraud_cpu/checkpoints/epoch_1 epoch=1 step=16
# 2026-07-24 22:27:02,295 | INFO | jenga_nlp.training.callbacks | Checkpoint saved (best): /content/jenganlp_fixture_mpesa_fraud_cpu/checkpoints/best
# 2026-07-24 22:27:02,296 | INFO | jenga_nlp.activity | [checkpoint] checkpoint_saved checkpoint saved: /content/jenganlp_fixture_mpesa_fraud_cpu/checkpoints/best epoch=1 step=16
# 2026-07-24 22:27:02,297 | INFO | jenga_nlp.activity | [train] epoch_started epoch 3 started epoch=2
# 2026-07-24 22:27:04,534 | INFO | jenga_nlp.activity | [train] step_logged step 17 loss 0.0745 step=17
# Training:  71% 17/24 [01:39<01:46, 15.19s/it, epoch=3, loss=0.0745]2026-07-24 22:27:06,484 | INFO | jenga_nlp.activity | [train] step_logged step 18 loss 0.1073 step=18
# Training:  75% 18/24 [01:41<01:07, 11.18s/it, epoch=3, loss=0.1073]2026-07-24 22:27:08,168 | INFO | jenga_nlp.activity | [train] step_logged step 19 loss 0.0473 step=19
# Training:  79% 19/24 [01:43<00:41,  8.32s/it, epoch=3, loss=0.0473]2026-07-24 22:27:09,984 | INFO | jenga_nlp.activity | [train] step_logged step 20 loss 0.0620 step=20
# Training:  83% 20/24 [01:44<00:25,  6.37s/it, epoch=3, loss=0.0620]2026-07-24 22:27:11,781 | INFO | jenga_nlp.activity | [train] step_logged step 21 loss 0.0479 step=21
# Training:  88% 21/24 [01:46<00:14,  5.00s/it, epoch=3, loss=0.0479]2026-07-24 22:27:14,036 | INFO | jenga_nlp.activity | [train] step_logged step 22 loss 0.0477 step=22
# Training:  92% 22/24 [01:49<00:08,  4.18s/it, epoch=3, loss=0.0477]2026-07-24 22:27:16,576 | INFO | jenga_nlp.activity | [train] step_logged step 23 loss 0.0414 step=23
# Training:  96% 23/24 [01:51<00:03,  3.69s/it, epoch=3, loss=0.0414]2026-07-24 22:27:18,434 | INFO | jenga_nlp.activity | [train] step_logged step 24 loss 0.0413 step=24
# Training: 100% 24/24 [01:53<00:00,  3.13s/it, epoch=3, loss=0.0413]2026-07-24 22:27:19,148 | INFO | jenga_nlp.training.trainer | Epoch 3/3 - Metrics: {'mpesa_fraud_detection_fraud_head_accuracy': 1.0, 'mpesa_fraud_detection_fraud_head_precision': 1.0, 'mpesa_fraud_detection_fraud_head_recall': 1.0, 'mpesa_fraud_detection_fraud_head_f1': 1.0, 'eval_loss': 0.04307088442146778, 'train_loss_avg': 0.05866610165685415}
# 2026-07-24 22:27:19,148 | INFO | jenga_nlp.activity | [eval] metrics_logged epoch 3 metrics logged epoch=2
# 2026-07-24 22:27:57,692 | INFO | jenga_nlp.training.callbacks | Checkpoint saved (epoch 2): /content/jenganlp_fixture_mpesa_fraud_cpu/checkpoints/epoch_2
# 2026-07-24 22:27:57,693 | INFO | jenga_nlp.activity | [checkpoint] checkpoint_saved checkpoint saved: /content/jenganlp_fixture_mpesa_fraud_cpu/checkpoints/epoch_2 epoch=2 step=24
# 2026-07-24 22:28:03,779 | INFO | jenga_nlp.training.callbacks | Checkpoint saved (best): /content/jenganlp_fixture_mpesa_fraud_cpu/checkpoints/best
# 2026-07-24 22:28:03,779 | INFO | jenga_nlp.activity | [checkpoint] checkpoint_saved checkpoint saved: /content/jenganlp_fixture_mpesa_fraud_cpu/checkpoints/best epoch=2 step=24
# Training: 100% 24/24 [02:38<00:00,  6.60s/it, epoch=3, loss=0.0413]
# 2026-07-24 22:28:03,780 | INFO | jenga_nlp.activity | [system] run_finished training finished
# 🏃 View run bright-chimp-361 at: https://d8e8-34-178-80-22.ngrok-free.app/#/experiments/2/runs/78a4f288fce5477ebe577a740f64f6e1
# 🧪 View experiment at: https://d8e8-34-178-80-22.ngrok-free.app/#/experiments/2
# 2026-07-24 22:28:04,553 | INFO | jenga_nlp.training.callbacks | Logger closed
# 2026-07-24 22:28:05,577 | INFO | jenga_nlp.core.model | Model saved to /content/jenganlp_fixture_mpesa_fraud_cpu
# 2026-07-24 22:28:05,603 | INFO | jenga_nlp.activity | [train] info training complete
# 2026-07-24 22:28:05,608 | INFO | jenga_nlp.activity | [system] info run finished: success

# %%
# Out:
# Found existing installation: torchvision 0.26.0+cpu
# Uninstalling torchvision-0.26.0+cpu:
#   Would remove:
#     /usr/local/lib/python3.12/dist-packages/torchvision-0.26.0+cpu.dist-info/*
#     /usr/local/lib/python3.12/dist-packages/torchvision.libs/libjpeg.b1a87dc0.so.8
#     /usr/local/lib/python3.12/dist-packages/torchvision.libs/libpng16.60f56faa.so.16
#     /usr/local/lib/python3.12/dist-packages/torchvision.libs/libsharpyuv.691ead6e.so.0
#     /usr/local/lib/python3.12/dist-packages/torchvision.libs/libwebp.e20c0bc7.so.7
#     /usr/local/lib/python3.12/dist-packages/torchvision.libs/libz.7dbeb23c.so.1
#     /usr/local/lib/python3.12/dist-packages/torchvision/*
# Proceed (Y/n)? y
#   Successfully uninstalled torchvision-0.26.0+cpu
